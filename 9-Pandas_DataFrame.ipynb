# %% [markdown]
# Pandas- DataFrame
#
# df= pd.DataFrame(data, index, columns)

# %%
import pandas as pd

# %%
movies = {
    1990: "Friends",
    1991: "Person of Interest",
    1992: "Heartland",
    1993: "Doctor Who",
    1994: "Merlin"
}

df = pd.DataFrame(movies.values())
df
# Out:
#                     0
# 0             Friends
# 1  Person of Interest
# 2           Heartland
# 3          Doctor Who
# 4              Merlin

# %%
df = pd.read_csv("movies.csv", engine= 'python')

df
# Out:
#       Unnamed: 0        id original_language               original_title  \
# 0              0  580489.0                en  Venom: Let There Be Carnage
# 1              1  524434.0                en                     Eternals
# 2              2  438631.0                en                         Dune
# 3              3  796499.0                en              Army of Thieves
# 4              4  550988.0                en                     Free Guy
# ...          ...       ...               ...                          ...
# 10009       9995     530.0                en              A Grand Day Out
# 10010       9996   15934.0                en                  El cantante
# 10011       9997  162215.0                en               How I Live Now
# 10012       9998    5723.0                en                         Once
# 10013       9999  311667.0                en              Manhattan Night
#
#        popularity release_date  vote_average  vote_count  \
# ...

# %%
df.head() #default olarak ilk 5 satırı gösteriri. head(n)-> n kadar satır gösterir.
# Out:
#   Unnamed: 0        id original_language               original_title  \
# 0          0  580489.0                en  Venom: Let There Be Carnage
# 1          1  524434.0                en                     Eternals
# 2          2  438631.0                en                         Dune
# 3          3  796499.0                en              Army of Thieves
# 4          4  550988.0                en                     Free Guy
#
#    popularity release_date  vote_average  vote_count  \
# 0    5401.308   2021-09-30           6.8      1736.0
# 1    3365.535   2021-11-03           7.1       622.0
# 2    2911.423   2021-09-15           8.0      3632.0
# 3    2552.437   2021-10-27           6.9       555.0
# 4    1850.470   2021-08-11           7.8      3493.0
#
#                                                genre  \
# 0         ['Science Fiction', 'Action', 'Adventure']
# 1  ['Action', 'Adventure', 'Science Fiction', 'Fa...
# 2         ['Action', 'Adventure', 'Science Fiction']
# ...

# %%
df.tail(2) #defaultu son 5 satırdır. tail(n)-> son n satırı okur
# Out:
#       Unnamed: 0        id original_language   original_title  popularity  \
# 10012       9998    5723.0                en             Once       9.267
# 10013       9999  311667.0                en  Manhattan Night       9.273
#
#       release_date  vote_average  vote_count  \
# 10012   2007-03-23           7.4       990.0
# 10013   2016-05-20           6.0       304.0
#
#                                   genre  \
# 10012     ['Drama', 'Music', 'Romance']
# 10013  ['Drama', 'Mystery', 'Thriller']
#
#                                                 overview     revenue  runtime  \
# 10012  A vacuum repairman moonlights as a street musi...  20710513.0     85.0
# 10013  Porter Wren is a Manhattan tabloid writer with...         0.0    113.0
#
#                                        tagline
# 10012  How often do you find the right person?
# 10013          No reporter can resist a siren.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10014 entries, 0 to 10013
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         10014 non-null  object
#  1   id                 10002 non-null  float64
#  2   original_language  10002 non-null  object
#  3   original_title     10001 non-null  object
#  4   popularity         10000 non-null  float64
#  5   release_date       9962 non-null   object
#  6   vote_average       10000 non-null  float64
#  7   vote_count         10000 non-null  float64
#  8   genre              10000 non-null  object
#  9   overview           9900 non-null   object
#  10  revenue            9998 non-null   float64
#  11  runtime            9989 non-null   float64
#  12  tagline            7079 non-null   object
# dtypes: float64(6), object(7)
# memory usage: 1017.2+ KB

# %%
df.describe().T
# Out:
#                 count          mean           std    min        25%  \
# id            10002.0  2.500031e+05  2.617323e+05  0.000  11864.500
# popularity    10000.0  3.451687e+01  1.006940e+02  6.269     11.908
# vote_average  10000.0  6.298750e+00  1.434260e+00  0.000      5.900
# vote_count    10000.0  1.315085e+03  2.501899e+03  0.000    118.000
# revenue        9998.0  5.737536e+07  1.480897e+08  0.000      0.000
# runtime        9989.0  9.879277e+01  2.877153e+01  0.000     89.000
#
#                      50%           75%           max
# id            144312.000  4.514060e+05  8.934780e+05
# popularity        17.488  2.962625e+01  5.401308e+03
# vote_average       6.500  7.100000e+00  9.500000e+00
# vote_count       425.500  1.297250e+03  3.018400e+04
# revenue       593124.000  4.768796e+07  2.847246e+09
# runtime           99.000  1.130000e+02  4.000000e+02

# %%
df.dtypes #sütunların typelarını alıyor
# Out:
# Unnamed: 0            object
# id                   float64
# original_language     object
# original_title        object
# popularity           float64
# release_date          object
# vote_average         float64
# vote_count           float64
# genre                 object
# overview              object
# revenue              float64
# runtime              float64
# tagline               object
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'original_language', 'original_title', 'popularity',
#        'release_date', 'vote_average', 'vote_count', 'genre', 'overview',
#        'revenue', 'runtime', 'tagline'],
#       dtype='object')

# %%
df = pd.read_csv("movies.csv", usecols = ['original_language', 'original_title', 'popularity',
       'release_date', 'vote_average', 'vote_count', 'genre', 'overview', #hangi sütunları göstereceğini yazıyoruz.
       'revenue', 'runtime', 'tagline'], engine = "python")

df.head(2)
# Out:
#   original_language               original_title  popularity release_date  \
# 0                en  Venom: Let There Be Carnage    5401.308   2021-09-30
# 1                en                     Eternals    3365.535   2021-11-03
#
#    vote_average  vote_count  \
# 0           6.8      1736.0
# 1           7.1       622.0
#
#                                                genre  \
# 0         ['Science Fiction', 'Action', 'Adventure']
# 1  ['Action', 'Adventure', 'Science Fiction', 'Fa...
#
#                                             overview      revenue  runtime  \
# 0  After finding a host body in investigative rep...  424000000.0     97.0
# 1  The Eternals are a team of ancient aliens who ...  165000000.0    157.0
#
#                tagline
# 0                  NaN
# 1  In the beginning...

# %%
df.rename(columns={"original_language": "Anadil"}, inplace=True) #sütun adını değiştiriyor.

df.head()
# Out:
#   Anadil               original_title  popularity release_date  vote_average  \
# 0     en  Venom: Let There Be Carnage    5401.308   2021-09-30           6.8
# 1     en                     Eternals    3365.535   2021-11-03           7.1
# 2     en                         Dune    2911.423   2021-09-15           8.0
# 3     en              Army of Thieves    2552.437   2021-10-27           6.9
# 4     en                     Free Guy    1850.470   2021-08-11           7.8
#
#    vote_count                                              genre  \
# 0      1736.0         ['Science Fiction', 'Action', 'Adventure']
# 1       622.0  ['Action', 'Adventure', 'Science Fiction', 'Fa...
# 2      3632.0         ['Action', 'Adventure', 'Science Fiction']
# 3       555.0                    ['Action', 'Crime', 'Thriller']
# 4      3493.0  ['Comedy', 'Action', 'Adventure', 'Science Fic...
#
#                                             overview      revenue  runtime  \
# ...

# %%
df.original_title
# Out:
# 0        Venom: Let There Be Carnage
# 1                           Eternals
# 2                               Dune
# 3                    Army of Thieves
# 4                           Free Guy
#                     ...
# 10009                A Grand Day Out
# 10010                    El cantante
# 10011                 How I Live Now
# 10012                           Once
# 10013                Manhattan Night
# Name: original_title, Length: 10014, dtype: object

# %%
df["original_title"]
# Out:
# 0        Venom: Let There Be Carnage
# 1                           Eternals
# 2                               Dune
# 3                    Army of Thieves
# 4                           Free Guy
#                     ...
# 10009                A Grand Day Out
# 10010                    El cantante
# 10011                 How I Live Now
# 10012                           Once
# 10013                Manhattan Night
# Name: original_title, Length: 10014, dtype: object

# %%
df ["language-title"]= df.Anadil + " - " + df.original_title

df.head(2)
# Out:
#   Anadil               original_title  popularity release_date  vote_average  \
# 0     en  Venom: Let There Be Carnage    5401.308   2021-09-30           6.8
# 1     en                     Eternals    3365.535   2021-11-03           7.1
#
#    vote_count                                              genre  \
# 0      1736.0         ['Science Fiction', 'Action', 'Adventure']
# 1       622.0  ['Action', 'Adventure', 'Science Fiction', 'Fa...
#
#                                             overview      revenue  runtime  \
# 0  After finding a host body in investigative rep...  424000000.0     97.0
# 1  The Eternals are a team of ancient aliens who ...  165000000.0    157.0
#
#                tagline                    language-title
# 0                  NaN  en - Venom: Let There Be Carnage
# 1  In the beginning...                     en - Eternals

# %%
#isnull & notnull

df.isnull()
# Out:
#        Anadil  original_title  popularity  release_date  vote_average  \
# 0       False           False       False         False         False
# 1       False           False       False         False         False
# 2       False           False       False         False         False
# 3       False           False       False         False         False
# 4       False           False       False         False         False
# ...       ...             ...         ...           ...           ...
# 10009   False           False       False         False         False
# 10010   False           False       False         False         False
# 10011   False           False       False         False         False
# 10012   False           False       False         False         False
# 10013   False           False       False         False         False
#
#        vote_count  genre  overview  revenue  runtime  tagline  language-title
# ...

# %%
df.notnull()
# Out:
#        Anadil  original_title  popularity  release_date  vote_average  \
# 0        True            True        True          True          True
# 1        True            True        True          True          True
# 2        True            True        True          True          True
# 3        True            True        True          True          True
# 4        True            True        True          True          True
# ...       ...             ...         ...           ...           ...
# 10009    True            True        True          True          True
# 10010    True            True        True          True          True
# 10011    True            True        True          True          True
# 10012    True            True        True          True          True
# 10013    True            True        True          True          True
#
#        vote_count  genre  overview  revenue  runtime  tagline  language-title
# ...

# %%
pd.isnull(df.tagline).sum()
# Out:
# 2935

# %% [markdown]
# devamını aysel hoca repodan al.
